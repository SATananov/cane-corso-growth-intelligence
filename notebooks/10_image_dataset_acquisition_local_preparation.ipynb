# %%
from pathlib import Path
import os
import sys

def find_project_root(start=None):
    current = Path(start or Path.cwd()).resolve()
    for candidate in [current, *current.parents]:
        if (
            (candidate / "README.md").exists()
            and (candidate / "src").is_dir()
            and (candidate / "data").is_dir()
            and (candidate / "notebooks").is_dir()
        ):
            return candidate
    raise RuntimeError("Project root was not found. Open this notebook from inside the project folder.")

PROJECT_ROOT = find_project_root()
ROOT = PROJECT_ROOT
root = PROJECT_ROOT
project_root = PROJECT_ROOT

os.chdir(PROJECT_ROOT)

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root configured")
print("Working directory configured")

# %% [markdown]
# # Image Dataset Acquisition and Local Preparation
#
# This notebook documents the practical local-data preparation stage for the future visual similarity visual-similarity module. It does not train an image model yet. The goal is to prepare a safe folder structure and data-governance workflow before any downloaded image dataset is used.
#
# This notebook is part of an optional exploratory visual-similarity extension. It is not presented as a core course requirement and it does not prove breed identity, pedigree, registry status or veterinary status.

# %% [markdown]
# ## Mathematical / ML Framing
#
# Future visual model idea:
#
# ```text
# image -> visual feature vector -> classifier -> softmax probabilities
# ```
#
# The model output should be interpreted as visual similarity among trained classes, not breed proof. The current stage prepares data acquisition and validation only.

# %% [markdown]
# ## Responsible Data Boundary
#
# Images may come from public datasets with documented terms, the user's own photos, or future owner-provided photos with explicit permission. Random web scraping from Google, Instagram, Facebook, breeder sites, or social-media posts is not acceptable for this project.

# %%
from pathlib import Path
import pandas as pd
project_root = next(candidate for candidate in [Path.cwd().resolve(), *Path.cwd().resolve().parents] if (candidate / "src").is_dir() and (candidate / "data").is_dir())
print(project_root)

# %% [markdown]
# ## Target Visual Classes
#
# The planned classes are still candidates. The final class list depends on real public dataset availability and permission terms.

# %%
classes = pd.read_csv(project_root / 'data' / 'molossoid_visual_target_classes.csv')
classes[['class_slug', 'display_name', 'role', 'dataset_availability_status']]

# %% [markdown]
# ## Local Inventory Template
#
# The project keeps a lightweight template for documenting local dataset downloads. This is not a replacement for checking the official source terms.

# %%
inventory = pd.read_csv(project_root / 'data' / 'image_dataset_local_inventory_template.csv')
inventory

# %% [markdown]
# ## Folder Preparation
#
# Run from the project root:
#
# ```powershell
# python src/prepare_image_dataset_structure.py
# python src/validate_local_image_dataset.py
# ```
#
# The scripts prepare and validate an ignored local folder under `data/images/local_dataset/`.

# %% [markdown]
# ## Conclusion
#
# this stage prepares the project for future image experiments, but it does not download public datasets, commit image files, or train a visual classifier. This keeps the project legally safer, lighter for the repository, and easier to explain during assessment.
