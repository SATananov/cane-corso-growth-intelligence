# %%
from pathlib import Path
import os
import sys

def find_project_root(start=None):
    current = Path(start or Path.cwd()).resolve()
    for candidate in [current, *current.parents]:
        if (
            (candidate / "README.md").exists()
            and (candidate / "src").is_dir()
            and (candidate / "data").is_dir()
            and (candidate / "notebooks").is_dir()
        ):
            return candidate
    raise RuntimeError("Project root was not found. Open this notebook from inside the project folder.")

PROJECT_ROOT = find_project_root()
ROOT = PROJECT_ROOT
root = PROJECT_ROOT
project_root = PROJECT_ROOT

os.chdir(PROJECT_ROOT)

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)
print("Working directory:", Path.cwd())

# %% [markdown]
# # Baseline Image Classifier Training Plan
#
# This notebook documents the planned first baseline image classifier for the Cane Corso Growth Intelligence visual-similarity extension.
#
# It does not train a model yet. It explains the model objective, data splits, metrics, and interpretation boundaries.
#
# This notebook is part of an optional exploratory visual-similarity extension. It is not presented as a core course requirement and it does not prove breed identity, pedigree, registry status or veterinary status.

# %% [markdown]
# ## Objective
#
# The future baseline model should estimate visual similarity among the selected local Stanford Dogs baseline classes.
#
# The model output should be interpreted as a probability distribution over the trained classes, not as a proof of breed, pedigree, registry identity, genetics, or health status.

# %% [markdown]
# ## Planned training pipeline
#
# 1. Load the local baseline subset manifest.
# 2. Read images from the local `train`, `validation`, and `test` split folders.
# 3. Resize images to a fixed input size, for example 224 × 224.
# 4. Use a pretrained image backbone.
# 5. Train a small classification head or use extracted features with a simple classifier.
# 6. Evaluate with accuracy, macro F1, per-class precision/recall, and a confusion matrix.

# %%
from pathlib import Path
ROOT = next(candidate for candidate in [Path.cwd().resolve(), *Path.cwd().resolve().parents] if (candidate / "src").is_dir() and (candidate / "data").is_dir())
plan_files = [
    ROOT / 'docs' / 'baseline_image_classifier_training_plan.md',
    ROOT / 'docs' / 'visual_similarity_training_safety_boundaries.md',
    ROOT / 'data' / 'baseline_image_classifier_training_plan.csv',
    ROOT / 'data' / 'baseline_image_classifier_metrics_plan.csv',
]

for path in plan_files:
    print(path, 'exists=', path.exists())

# %% [markdown]
# ## Boundary
#
# The correct interpretation is:
#
# > The model estimates visual similarity among the classes it was trained on. It does not prove breed, pedigree, genetic origin, health status, or official registry identity.

# %%
# Optional validation command for the project terminal:
# python src/validate_baseline_image_classifier_training_plan.py
