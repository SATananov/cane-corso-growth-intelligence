# %%
from pathlib import Path
import os
import sys

def find_project_root(start=None):
    current = Path(start or Path.cwd()).resolve()
    for candidate in [current, *current.parents]:
        if (
            (candidate / "README.md").exists()
            and (candidate / "src").is_dir()
            and (candidate / "data").is_dir()
            and (candidate / "notebooks").is_dir()
        ):
            return candidate
    raise RuntimeError("Project root was not found. Open this notebook from inside the project folder.")

PROJECT_ROOT = find_project_root()
ROOT = PROJECT_ROOT
root = PROJECT_ROOT
project_root = PROJECT_ROOT

os.chdir(PROJECT_ROOT)

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)
print("Working directory:", Path.cwd())

# %% [markdown]
# # Baseline Image Subset Preparation
#
# This notebook documents the local preparation stage for the first Stanford Dogs visual-similarity baseline subset.
#
# The goal is not to train the image model yet. The goal is to prepare a small, reproducible train/validation/test subset from the selected Stanford Dogs classes.
#
# This notebook is part of an optional exploratory visual-similarity extension. It is not presented as a core course requirement and it does not prove breed identity, pedigree, registry status or veterinary status.

# %% [markdown]
# ## Responsible interpretation boundary
#
# The future image classifier must be described as a **visual similarity classifier**, not as official breed proof.
#
# It does not prove pedigree, genetics, registry status, USG recognition, certification or veterinary condition.

# %%
from pathlib import Path
ROOT = next(candidate for candidate in [Path.cwd().resolve(), *Path.cwd().resolve().parents] if (candidate / "src").is_dir() and (candidate / "data").is_dir())
selection_report = ROOT / 'reports' / 'stanford_dogs_baseline_class_selection.csv'
subset_manifest = ROOT / 'reports' / 'stanford_dogs_baseline_subset_manifest.csv'
subset_summary = ROOT / 'reports' / 'stanford_dogs_baseline_subset_summary.md'

selection_report.exists(), subset_manifest.exists(), subset_summary.exists()

# %%
# Prepare the local subset. This copies images only into data/images/local_dataset/splits/,
# which is ignored by Git and must remain local-only.
# !python src/prepare_stanford_dogs_baseline_subset.py

# %%
# Validate the local subset manifest and copied local image files.
# !python src/validate_stanford_dogs_baseline_subset.py

# %% [markdown]
# ## Expected result
#
# After preparation, the project should have a local-only split folder and report files:
#
# ```text
# data/images/local_dataset/splits/stanford_dogs_first_baseline/
# reports/stanford_dogs_baseline_subset_manifest.csv
# reports/stanford_dogs_baseline_subset_summary.md
# ```
#
# Only the reports and CSV manifest should be committed. The images should not be committed.
