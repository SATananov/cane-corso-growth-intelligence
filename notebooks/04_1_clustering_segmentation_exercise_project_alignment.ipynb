# %% [markdown]
# # Clustering Exercise Project Alignment
#
# This notebook connects the course clustering exercise to the Cane Corso Growth Intelligence project. The goal is to show how the exercise workflow can be translated from customer segmentation to educational growth-state segmentation.

# %% [markdown]
# ## Research question
#
# Can growth-state observations be grouped into interpretable segments, and can cluster-derived features help explain later growth behaviour in a small educational dataset?

# %% [markdown]
# ## Exercise mapping
#
# The original exercise focuses on segmentation, cleaning policy, chronological splitting, KMeans, a second clustering algorithm, segment profiling, stability checks, clustering versus classification, and testing cluster-derived features.

# %%
from pathlib import Path
import pandas as pd

root = Path.cwd()
if not (root / 'src').exists():
    root = root.parent

requirements = pd.read_csv(root / 'data' / 'course_exercises' / 'clustering_segmentation_exercise_requirements.csv')
requirements

# %% [markdown]
# ## Run the project alignment workflow
#
# The script creates engineered growth features, evaluates KMeans, compares an additional clustering algorithm, builds segment profiles, checks cluster stability, and tests cluster-derived features in a small supervised comparison.

# %%
from pathlib import Path
import subprocess
import sys


def project_root_from_notebook():
    current = Path.cwd().resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "src").exists() and (candidate / "data").exists():
            return candidate
    raise RuntimeError("Project root not found. Open the notebook from the project folder.")


PROJECT_ROOT = project_root_from_notebook()


def run_project_script(relative_script):
    script_path = PROJECT_ROOT / relative_script
    result = subprocess.run(
        [sys.executable, str(script_path)],
        cwd=PROJECT_ROOT,
        text=True,
        capture_output=True,
    )
    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print(result.stderr)
    result.check_returncode()
    return result.returncode


run_project_script(Path("src/run_clustering_exercise_alignment.py"))

# %% [markdown]
# ## Validate outputs
#
# The validation script checks that the exercise mapping, metrics, segment profiles, stability analysis, visualization plan, and supervised feature comparison were produced.

# %%
from pathlib import Path
import subprocess
import sys


def project_root_from_notebook():
    current = Path.cwd().resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "src").exists() and (candidate / "data").exists():
            return candidate
    raise RuntimeError("Project root not found. Open the notebook from the project folder.")


PROJECT_ROOT = project_root_from_notebook()


def run_project_script(relative_script):
    script_path = PROJECT_ROOT / relative_script
    result = subprocess.run(
        [sys.executable, str(script_path)],
        cwd=PROJECT_ROOT,
        text=True,
        capture_output=True,
    )
    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print(result.stderr)
    result.check_returncode()
    return result.returncode


run_project_script(Path("src/validate_clustering_exercise_alignment.py"))

# %% [markdown]
# ## Clustering metrics

# %%
pd.read_csv(root / 'reports' / 'course_exercises' / 'clustering_exercise_alignment_metrics.csv')

# %% [markdown]
# ## Segment profiles

# %%
pd.read_csv(root / 'reports' / 'course_exercises' / 'clustering_exercise_segment_profiles.csv')

# %% [markdown]
# ## Cluster-derived features
#
# The exercise asks whether cluster-derived features are useful for supervised prediction. The project tests original growth features, cluster-distance features, and the combined representation.

# %%
pd.read_csv(root / 'reports' / 'course_exercises' / 'clustering_exercise_cluster_feature_comparison.csv')

# %% [markdown]
# ## Interpretation
#
# The segmentation is an educational modelling layer. It can help describe growth-state patterns and generate hypotheses, but it is not a medical diagnosis and is not evidence of breed identity or pedigree.
