# %% [markdown]
# # First Public Image Dataset Candidate / Download Guide
#
# This notebook documents the first public image dataset candidate for the future visual similarity module. It does not download images and does not train an image model.
#
# This notebook is part of an optional exploratory visual-similarity extension. It is not presented as a core course requirement and it does not prove breed identity, pedigree, registry status or veterinary status.

# %%
from pathlib import Path
import sys


def find_project_root(start=None):
    start = Path.cwd() if start is None else Path(start)
    for candidate in [start, *start.parents]:
        if (candidate / "src").exists() and (candidate / "data").exists():
            return candidate
    raise RuntimeError("Project root not found. Open this notebook from the project folder or adjust the working directory.")


PROJECT_ROOT = find_project_root()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(f"Notebook ready. Project root: {PROJECT_ROOT}")

# %% [markdown]
# ## Responsible framing
#
# The future model should be described as a **visual similarity classifier**, not breed proof. A photo cannot prove pedigree, registry status, genetic origin, or veterinary status.

# %% [markdown]
# ## Mathematical view
#
# An image can be represented as a tensor:
#
# ```text
# x_image ∈ R^(H × W × 3)
# ```
#
# A future classifier will produce a probability vector over confirmed classes:
#
# ```text
# p = [P(class_1 | x), P(class_2 | x), ..., P(class_k | x)]
# ```
#
# this stage only prepares the dataset candidate; it does not estimate `p`.

# %%
from pathlib import Path
import csv

root = Path.cwd().resolve()
candidate_path = root / 'data' / 'first_public_image_dataset_candidate.csv'
with candidate_path.open('r', encoding='utf-8', newline='') as file:
    rows = list(csv.DictReader(file))
rows

# %%
import subprocess

subprocess.run([sys.executable, str(PROJECT_ROOT / "src" / "validate_first_public_image_dataset_candidate.py")], check=True)

# %%
import subprocess

subprocess.run([sys.executable, str(PROJECT_ROOT / "src" / "inspect_stanford_dogs_local_dataset.py")], check=True)

# %% [markdown]
# ## Next stage
#
# After the dataset is downloaded locally, the next stage is to inspect the real labels and choose the first baseline classes. If Cane Corso or other target molossoid breeds are missing, the project must say so honestly and use only confirmed available classes.
