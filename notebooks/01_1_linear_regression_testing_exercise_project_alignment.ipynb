# %% [markdown]
# # Linear Regression Testing Exercise Alignment
#
# This notebook connects the course exercise on linear regression, regularization, and testing to the Cane Corso Growth Intelligence project.
#
# The original exercise uses a retail sales dataset. In this project, the same machine-learning workflow is adapted to growth-weight prediction. The goal is to show the process clearly: formulate the question, inspect data, preprocess features, split data, train a baseline, evaluate, compare models, tune a hyperparameter, and interpret limitations.

# %%
from pathlib import Path
import sys


def find_project_root(start=None):
    start = Path.cwd() if start is None else Path(start)
    for candidate in [start, *start.parents]:
        if (candidate / "src").exists() and (candidate / "data").exists():
            return candidate
    raise RuntimeError("Project root not found. Open this notebook from the project folder or adjust the working directory.")


PROJECT_ROOT = find_project_root()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(f"Notebook ready. Project root: {PROJECT_ROOT}")

# %% [markdown]
# ## Research question
#
# **Domain question:** can growth records help owners monitor whether a large-breed dog is following a stable educational growth pattern?
#
# **Data science question:** can regression models predict `weight_kg` from features such as `age_months`, `height_cm`, `sex`, and `activity_level`?
#
# The result is not veterinary advice. It is an educational regression workflow.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd()
requirements_path = ROOT / 'data' / 'course_exercises' / 'linear_regression_testing_exercise_requirements.csv'
requirements = pd.read_csv(requirements_path)
requirements

# %% [markdown]
# ## Exercise coverage summary
#
# The table below shows how each exercise task is represented in the project. Some details are adapted to the project domain rather than copied from the original retail dataset.

# %%
requirements[['problem_number', 'exercise_requirement', 'coverage_status', 'evidence_file']]

# %% [markdown]
# ## Run the compact alignment workflow
#
# The script below compares three regression approaches:
#
# 1. age-only linear regression baseline;
# 2. enriched linear regression with numeric and categorical preprocessing;
# 3. tuned Ridge regression with a small `alpha` grid.

# %%
import subprocess

subprocess.run([sys.executable, str(PROJECT_ROOT / "src" / "run_linear_regression_exercise_alignment.py")], check=True)

# %% [markdown]
# ## Compare model metrics
#
# The exercise asks for several evaluation metrics. This project uses MAE, RMSE, and R2 so the baseline and alternative models can be compared in a consistent way.

# %%
metrics_path = ROOT / 'reports' / 'course_exercises' / 'linear_regression_exercise_alignment_metrics.csv'
metrics = pd.read_csv(metrics_path)
metrics

# %% [markdown]
# ## Visual check
#
# A visual check is useful because regression metrics alone may hide systematic errors. The main regression notebook already includes plotted comparisons. This alignment notebook keeps the visual analysis concept explicit and uses the metrics report as a reproducible reference.

# %% [markdown]
# ## Interpretation
#
# The exercise workflow is represented in the project through a simple baseline, changed preprocessing, model comparison, and a small hyperparameter search.
#
# The prototype dataset is small, so strong metrics should not be interpreted as proof of a reliable biological model. The purpose is to demonstrate the regression workflow and connect it to the project domain.
