# %% [markdown]
# # Dimensionality Reduction Course Topic
#
# This notebook is reserved for the future course topic **Dimensionality Reduction**.
#
# Planned project direction: apply dimensionality reduction to high-dimensional growth profiles and, where appropriate, to selected image-derived features. The goal will be visualization and interpretation, not a new claim about breed identity or health diagnosis.
# It is intentionally not implemented yet because the topic has not been covered in class. After the lecture and exercise are completed, this notebook will be filled with the project-specific method, mathematics, code, results and limitations.
