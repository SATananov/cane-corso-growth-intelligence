# %%
from pathlib import Path
import os
import sys

def find_project_root(start=None):
    current = Path(start or Path.cwd()).resolve()
    for candidate in [current, *current.parents]:
        if (
            (candidate / "README.md").exists()
            and (candidate / "src").is_dir()
            and (candidate / "data").is_dir()
            and (candidate / "notebooks").is_dir()
        ):
            return candidate
    raise RuntimeError("Project root was not found. Open this notebook from inside the project folder.")

PROJECT_ROOT = find_project_root()
ROOT = PROJECT_ROOT
root = PROJECT_ROOT
project_root = PROJECT_ROOT

os.chdir(PROJECT_ROOT)

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)
print("Working directory:", Path.cwd())

# %% [markdown]
# # Classification Pipeline Exercise Alignment
#
# This notebook connects the course classification exercise workflow to the Cane Corso Growth Intelligence project. The original exercise teaches binary classification, reproducible experimental protocols, dummy baselines, preprocessing pipelines, model comparison, feature engineering, feature importance, and error analysis. Here those ideas are applied to an educational growth-interval classification task.

# %% [markdown]
# ## Project task
#
# The project classification question is whether a growth interval belongs to a faster-growth period based on previous measurements and metadata. This is a learning proxy, not a veterinary conclusion.

# %% [markdown]
# ## Exercise concepts covered
#
# - Data inspection and target balance
# - Fixed evaluation protocol
# - Dummy classifiers
# - Numeric and categorical preprocessing pipeline
# - Logistic regression baseline
# - Learning curve
# - Feature engineering
# - Alternative classifier comparison
# - Permutation importance
# - Error analysis
# - Feature-group ablation

# %%
from pathlib import Path
import pandas as pd
root = next(candidate for candidate in [Path.cwd().resolve(), *Path.cwd().resolve().parents] if (candidate / "src").is_dir() and (candidate / "data").is_dir())
requirements = pd.read_csv(root / 'data/course_exercises/classification_pipeline_reproducibility_requirements.csv')
requirements

# %% [markdown]
# ## Run the alignment workflow
#
# The script writes metrics, error analysis, feature importance, ablation, learning-curve, and summary reports under `reports/course_exercises/`.

# %%
from pathlib import Path
import subprocess
import sys


def project_root_from_notebook():
    current = Path.cwd().resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "src").exists() and (candidate / "data").exists():
            return candidate
    raise RuntimeError("Project root not found. Open the notebook from the project folder.")


PROJECT_ROOT = project_root_from_notebook()


def run_project_script(relative_script):
    script_path = PROJECT_ROOT / relative_script
    result = subprocess.run(
        [sys.executable, str(script_path)],
        cwd=PROJECT_ROOT,
        text=True,
        capture_output=True,
    )
    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print(result.stderr)
    result.check_returncode()
    return result.returncode


run_project_script(Path("src/run_classification_exercise_alignment.py"))

# %%
metrics = pd.read_csv(root / 'reports/course_exercises/classification_exercise_alignment_metrics.csv')
metrics

# %%
ablation = pd.read_csv(root / 'reports/course_exercises/classification_exercise_ablation_study.csv')
ablation

# %%
importance = pd.read_csv(root / 'reports/course_exercises/classification_exercise_feature_importance.csv')
importance

# %%
errors = pd.read_csv(root / 'reports/course_exercises/classification_exercise_error_analysis.csv')
errors.head(10)

# %% [markdown]
# ## Interpretation
#
# The output demonstrates a classification workflow, not a real health decision. Because the dataset is small and the target is a proxy derived from growth intervals, results should be read as a reproducible course exercise alignment rather than as a production model.

# %%
from pathlib import Path
import subprocess
import sys


def project_root_from_notebook():
    current = Path.cwd().resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "src").exists() and (candidate / "data").exists():
            return candidate
    raise RuntimeError("Project root not found. Open the notebook from the project folder.")


PROJECT_ROOT = project_root_from_notebook()


def run_project_script(relative_script):
    script_path = PROJECT_ROOT / relative_script
    result = subprocess.run(
        [sys.executable, str(script_path)],
        cwd=PROJECT_ROOT,
        text=True,
        capture_output=True,
    )
    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print(result.stderr)
    result.check_returncode()
    return result.returncode


run_project_script(Path("src/validate_classification_exercise_alignment.py"))
