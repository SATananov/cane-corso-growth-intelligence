# %%
from pathlib import Path
import os
import sys

def find_project_root(start=None):
    current = Path(start or Path.cwd()).resolve()
    for candidate in [current, *current.parents]:
        if (
            (candidate / "README.md").exists()
            and (candidate / "src").is_dir()
            and (candidate / "data").is_dir()
            and (candidate / "notebooks").is_dir()
        ):
            return candidate
    raise RuntimeError("Project root was not found. Open this notebook from inside the project folder.")

PROJECT_ROOT = find_project_root()
ROOT = PROJECT_ROOT
root = PROJECT_ROOT
project_root = PROJECT_ROOT

os.chdir(PROJECT_ROOT)

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root configured")
print("Working directory configured")

# %% [markdown]
# # Feature Engineering and Time Series Exercise Alignment
#
# This notebook connects the course exercise on time-based feature engineering with the Cane Corso Growth Intelligence project. The original exercise uses traffic-volume forecasting; this project applies the same ideas to longitudinal dog-growth measurements.

# %% [markdown]
# ## Exercise concepts covered
#
# The project version covers problem formulation, time-axis audit, baseline forecasting, iterative feature improvement, categorical feature use, sklearn pipelines, chronological testing, feature ablation, residual analysis, and direct versus recursive forecasting discussion.

# %% [markdown]
# ## Domain adaptation
#
# The target is `weight_kg`. The time component is represented by `age_months`, and a derived `measurement_date` is used only for audit and chronological modelling demonstrations. The result is educational and does not make veterinary claims.

# %%
from pathlib import Path
import sys
ROOT = next(candidate for candidate in [Path.cwd().resolve(), *Path.cwd().resolve().parents] if (candidate / "src").is_dir() and (candidate / "data").is_dir())
if not (ROOT / 'src').exists():
    ROOT = ROOT.parent
sys.path.append(str(ROOT / 'src'))

print(ROOT)

# %%
from pathlib import Path
import subprocess
import sys


def project_root_from_notebook():
    current = Path.cwd().resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "src").exists() and (candidate / "data").exists():
            return candidate
    raise RuntimeError("Project root not found. Open the notebook from the project folder.")


PROJECT_ROOT = project_root_from_notebook()


def run_project_script(relative_script):
    script_path = PROJECT_ROOT / relative_script
    result = subprocess.run(
        [sys.executable, str(script_path)],
        cwd=PROJECT_ROOT,
        text=True,
        capture_output=True,
    )
    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print(result.stderr)
    result.check_returncode()
    return result.returncode


run_project_script(Path("src/run_feature_engineering_time_series_exercise_alignment.py"))

# %%
from pathlib import Path
import subprocess
import sys


def project_root_from_notebook():
    current = Path.cwd().resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "src").exists() and (candidate / "data").exists():
            return candidate
    raise RuntimeError("Project root not found. Open the notebook from the project folder.")


PROJECT_ROOT = project_root_from_notebook()


def run_project_script(relative_script):
    script_path = PROJECT_ROOT / relative_script
    result = subprocess.run(
        [sys.executable, str(script_path)],
        cwd=PROJECT_ROOT,
        text=True,
        capture_output=True,
    )
    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print(result.stderr)
    result.check_returncode()
    return result.returncode


run_project_script(Path("src/validate_feature_engineering_time_series_exercise_alignment.py"))

# %% [markdown]
# ## Interpretation
#
# This alignment demonstrates the feature-engineering and time-series workflow on a small prototype dataset. The key learning value is the process: leakage-aware chronological splitting, lag and rolling-window features, categorical variables, comparable experiments, ablation, and residual analysis. A larger real longitudinal dataset would be required for reliable production forecasting.
