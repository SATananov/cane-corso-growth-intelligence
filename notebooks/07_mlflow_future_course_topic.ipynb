# %% [markdown]
# # MLflow Course Topic
#
# This notebook is reserved for the future course topic **MLflow**.
#
# Planned project direction: track experiments, parameters, metrics and artifacts for the tabular growth models and lightweight visual-similarity experiments. The goal will be reproducibility and transparent model comparison.
# It is intentionally not implemented yet because the topic has not been covered in class. After the lecture and exercise are completed, this notebook will be filled with the project-specific method, mathematics, code, results and limitations.
