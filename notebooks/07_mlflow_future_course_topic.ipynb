# %% [markdown]
# # MLflow Course Topic
#
# This notebook is reserved for the future course topic **MLflow**.
#
# Planned project direction: track experiments, parameters, metrics and artifacts for the tabular growth models and the lightweight visual-similarity experiment. The purpose will be reproducibility, transparent comparison and clearer model evaluation.
#
# The topic is intentionally reserved rather than implemented as a complete experiment. After the lecture and exercise are completed, this notebook should be expanded with the relevant workflow, code, results, limitations and project-specific interpretation.
